# %%
#!/usr/bin/python
import math
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from math import floor

# %%
#Cargando nrc_lexicon al vector ncr_lexicon [[palabra,anger,antici,disgu,fear,joy,negati,posi,sadness,surprise,trust],[...]]
n = open("nrc.txt", 'r+')
linea = n.readline()
pal_senti_emoci = []
nrc_lexicon = []

# %%
#No olvides :Añadir un enter al ultimo elemento de nrc.txt
while linea != "\n":
    tokens = nltk.word_tokenize(linea)
    for token in tokens:
        pal_senti_emoci.append(token)
    nrc_lexicon.append(pal_senti_emoci)
    pal_senti_emoci = []
    linea = n.readline()
n.close()

# %%
#Definiendo 8 emociones básicas + 2 sentimientos
positive = 0 
negative = 0
anger = 0 
fear = 0 
anticipation = 0 
trust = 0 
surprise = 0 
sadness = 0 
joy = 0  
disgust = 0

# %%
#Definiendo scores
num_pal = 0
num_pal_emo = 0
oe = 0 
e1 = 0 
e2 = 0

# %%
#Funcion nrc
def _nrc(pal_novela):
    #print ("Pal analizada:  "+pal_novela)
    global positive 
    global negative 
    global anger  
    global fear  
    global anticipation 
    global trust 
    global surprise 
    global sadness 
    global joy  
    global disgust
    global num_pal 
    global num_pal_emo 
 
    for emoWord in nrc_lexicon:
        if emoWord[0] == pal_novela:
            num_pal_emo += 1
            if emoWord[1] == "1":
                positive += 1
            if emoWord[2] == "1":
                negative += 1
            if emoWord[3] == "1":
                anger += 1
            if emoWord[4] == "1":
                anticipation += 1
            if emoWord[5] == "1":
                disgust += 1
            if emoWord[6] == "1":
                fear += 1
            if emoWord[7] == "1":
                joy += 1
            if emoWord[8] == "1":
                sadness += 1
            if emoWord[9] == "1":
                surprise += 1
            if emoWord[10] == "1":
                trust += 1

# %% [markdown]
# Compila lo siguiente, si vas a cambiar de libro, para que se limpie

# %%
positive = 0 
negative = 0
anger = 0 
fear = 0 
anticipation = 0 
trust = 0 
surprise = 0 
sadness = 0 
joy = 0  
disgust = 0
num_pal = 0
num_pal_emo = 0
oe = 0 
e1 = 0 
e2 = 0

# %%
#Leyendo toda la novela literaria
stopWords = set(stopwords.words('english'))
f = open("Libros/clock_total.txt", 'r+')
linea = f.readline()
while linea != "":
    if len(linea) > 1:
            tokens = nltk.word_tokenize(linea)
            for token in tokens:
                if True:# wordnet.synsets(token): #and (token not in stopWords): #Si la palabra pertenece al diccionario y no es stopword
                    #print(token)    
                    num_pal += 1 
                    _nrc(token)
    linea = f.readline()
f.close()
print("done...")
# Out:
# done...

# %%
#Obteneindo densidades de toda la novela
list_emo = []
list_emo.append(anger)
list_emo.append(fear)
list_emo.append(surprise)
list_emo.append(sadness)
list_emo.append(joy)
list_emo.append(disgust)
list_emo.append(anticipation)
list_emo.append(trust)

list_emo = sorted(list_emo) #Ordena
e1_emo = list_emo[len(list_emo)-1] #1ra mas predo
e2_emo = list_emo[len(list_emo)-2] #2da mas predo
oe = num_pal_emo / num_pal #overall density
e1 = e1_emo / num_pal
e2 = e2_emo / num_pal

# %%
print ("anger = ",anger)
print ("fear = ",fear)
print ("surprise = ",surprise)
print ("sadness = ",sadness)
print ("joy = ",joy)
print ("dis = ",disgust)
print ("antici = ",anticipation)
print ("trust = ",trust)
print ("oe = ",oe)
print ("pal_positivas = ",positive)
print ("pal_negativas = ",negative)
print ("pal_total = ",num_pal)
print ("pal_total_emo = ",num_pal_emo)
# Out:
# anger =  21
# fear =  19
# surprise =  15
# sadness =  15
# joy =  20
# dis =  22
# antici =  23
# trust =  21
# oe =  0.14463840399002495
# pal_positivas =  33
# pal_negativas =  38
# pal_total =  1203
# pal_total_emo =  174

# %%
#Cambiando cantidades
num_pal  -= anticipation
#Peter
'''joy = trust
trust = anticipation'''
#Alice
'''fear = trust
trust = anticipation'''
#Anne
'''joy = trust
trust = anticipation'''
#Ruiseñor
'''fear = anticipation'''
#Señor de las Moscas --?
'''sadness = anticipation '''

sadness = trust
fear = anticipation

# %%
#Calculando Activity score && Joy-Sad
activas = (joy/num_pal + anger/num_pal) 
pasivas = sadness/num_pal

print("activity: ",(activas-pasivas))
print("joy-sad: ",joy/num_pal - sadness/num_pal)
# Out:
# activity:  0.009212249643135696
# joy-sad:  -0.002222124115197269

# %%
#Densidades por emoción
print ("anger density = ",anger/num_pal)
print ("fear density = ",fear/num_pal)
print ("surprise density = ",surprise/num_pal)
print ("sadness density = ",sadness/num_pal)
print ("joy density = ",joy/num_pal)
print ("dis density = ",disgust/num_pal)
print ("antici density = ",anticipation/num_pal)
print ("trust density = ",trust/num_pal)
# Out:
# anger density =  0.0056199744459281605
# fear density =  0.006993745977155044
# surprise density =  0.004275023296475267
# sadness density =  0.0071378478860249965
# joy density =  0.008665328120046497
# dis density =  0.0039579990969613715
# antici density =  0.008886284380313757
# trust density =  0.008886284380313757

# %%
#Densidades por emoción
print ("anger density = ",anger/num_pal_emo)
print ("fear density = ",fear/num_pal_emo)
print ("surprise density = ",surprise/num_pal_emo)
print ("sadness density = ",sadness/num_pal_emo)
print ("joy density = ",joy/num_pal_emo)
print ("dis density = ",disgust/num_pal_emo)
print ("antici density = ",anticipation/num_pal_emo)
print ("trust density = ",trust/num_pal_emo)
# Out:
# anger density =  0.07605140186915887
# fear density =  0.10642523364485981
# surprise density =  0.05397196261682243
# sadness density =  0.1014018691588785
# joy density =  0.06647196261682244
# dis density =  0.05735981308411215
# antici density =  0.09357476635514018
# trust density =  0.09941588785046729

# %%
# Out:
# activity:  0.014416648904218418
# joy-sad:  0.003080977386788612

# %%
#Emociones por subsecciones
anger_ss = []
joy_ss = []
sadness_ss = []

# %%
#Dividiendo la novela por subsecciones (16)
def read_file(cant_pal ,can_texto,total,num_secciones):
    global positive 
    global negative 
    global anger  
    global fear  
    global anticipation 
    global trust 
    global surprise 
    global sadness 
    global joy  
    global disgust
    global num_pal 
    global num_pal_emo
    global oe
    global e1
    global e2
    global e3    
    global anger_ss
    global joy_ss 
    global sadness_ss 

    positive = 0
    negative = 0
    anger = 0
    fear = 0
    anticipation = 0
    trust = 0
    surprise = 0
    sadness = 0
    joy = 0
    disgust = 0
    num_pal = 0
    num_pal_emo = 0
    oe = 0
    e1 = 0
    e2 = 0
    e3 = 0

    den_o = []
    den_e1 = []
    den_e2 = []
    den_e3 = []

    f = open("Libros/dark_total.txt", 'r+')
    linea = f.readline()
    seccion = 1
    t = can_texto
    #print("cant: ",cant_pal)
    #print("parte: ",can_texto)
    
    while linea != "":
        if len(linea) > 1 :
            
            tokens = nltk.word_tokenize(linea)
            for token in tokens:
                
                if True:# wordnet.synsets(token): #and (token not in stopWords): #Si la palabra pertenece al diccionario y no es stopword
                    #print(token) 
                    cant_pal += 1   
                    num_pal += 1 
                    _nrc(token)
                    #print("num: ",num_pal, "cant ",cant_pal)
                if cant_pal == t:
                   #Imprimimos
                    print("-----------------------------------")
                    print("Seccion: ",seccion)
                    print ("anger = ",anger)
                    print ("fear = ",fear)
                    print ("surprise = ",surprise)
                    print ("sadness = ",sadness)
                    print ("joy = ",joy)
                    print ("dis = ",disgust)
                    print ("antici = ",anticipation)
                    print ("trust = ",trust)
                    print ("pal_positivas = ",positive)
                    print ("pal_negativas = ",negative)
                    print ("pal_total = ",num_pal)
                    print ("pal_total_emo = ",num_pal_emo)
                    #Añadiendo las emociones por subseccion
                    anger_ss.append(anger)
                    joy_ss.append(joy)
                    sadness_ss.append(sadness)
                    #Calculando Densidades
                    list_emo = []
                    list_emo.append(anger)
                    list_emo.append(fear)
                    list_emo.append(surprise)
                    list_emo.append(sadness)
                    list_emo.append(joy)
                    list_emo.append(disgust)
                    list_emo.append(anticipation)
                    list_emo.append(trust)

                    list_emo = sorted(list_emo)
                    e1_emo = list_emo[len(list_emo)-1]
                    e2_emo = list_emo[len(list_emo)-2]
                    e3_emo = list_emo[len(list_emo)-3]
                    oe = num_pal_emo / num_pal #overall density
                    e1 = e1_emo / num_pal
                    e2 = e2_emo / num_pal
                    e3 = e3_emo / num_pal

                    '''den_o.append(oe)
                    den_e1.append(e1)
                    den_e2.append(e2)
                    den_e3.append(e3)
                    print ("oe: ",oe)
                    print ("e1: ",e1)
                    print ("e2: ",e2)
                    print ("e3: ",e3)'''
                    
                    #Reinician los valores
                    positive = 0
                    negative = 0
                    anger = 0
                    fear = 0
                    anticipation = 0
                    trust = 0
                    surprise = 0
                    sadness = 0
                    joy = 0
                    disgust = 0
                    oe = 0
                    e1 = 0
                    e2 = 0
                    e3 = 0
                    num_pal = 0
                    num_pal_emo = 0
                    cant_pal = t 
                    if seccion == (num_secciones - 1):
                        t = total
                    else:
                        t = t + can_texto
                    seccion += 1
                    #print("cant: ",cant_pal)
                    #print("parte: ",t)
        linea = f.readline()
    '''print(den_o)
    print(den_e1)
    print(den_e2)
    print(den_e3)'''
    print("joy densities sum: ",sum(joy_ss))
    print("anger densities sum: ",sum(anger_ss))
    print("sadness densities sum: ",sum(sadness_ss))
       
    f.close()

# %%
#Obteniendo los datos por subseccion
num_secciones = 16
read_file(0,floor(num_pal/num_secciones),num_pal,num_secciones)
print("done...")
# Out:
# -----------------------------------
# Seccion:  1
# anger =  35
# fear =  47
# surprise =  29
# sadness =  44
# joy =  38
# dis =  17
# antici =  50
# trust =  39
# pal_positivas =  112
# pal_negativas =  85
# pal_total =  2747
# pal_total_emo =  543
# -----------------------------------
# Seccion:  2
# anger =  22
# fear =  41
# surprise =  21
# sadness =  39
# joy =  40
# dis =  27
# antici =  55
# trust =  59
# pal_positivas =  98
# pal_negativas =  74
# pal_total =  2747
# pal_total_emo =  477
# -----------------------------------
# Seccion:  3
# anger =  47
# fear =  62
# surprise =  23
# sadness =  51
# joy =  35
# dis =  47
# antici =  51
# trust =  54
# pal_positivas =  96
# pal_negativas =  107
# pal_total =  2747
# pal_total_emo =  545
# -----------------------------------
# Seccion:  4
# anger =  45
# fear =  58
# surprise =  27
# sadness =  62
# joy =  32
# dis =  42
# antici =  55
# trust =  48
# pal_positivas =  74
# pal_negativas =  110
# pal_total =  2747
# ...

# %%
#Activity por score aa
activas = (sum(joy_ss) + sum(anger_ss)) / 32
pasivas = (sum(sadness_ss)) / 16
print("activas: ",activas)
print("pasivas: ",pasivas)
print("activity score: ",activas - pasivas)
# Out:
# activas:  36.03125
# pasivas:  50.5625
# activity score:  -14.53125

# %%
#Activity por score bb
activas = (sum(joy_ss)/16 + sum(anger_ss)/16)/2
pasivas = sum(sadness_ss) / 16
print("activas: ",activas)
print("pasivas: ",pasivas)
print("activity score: ",activas - pasivas)
# Out:
# activas:  36.03125
# pasivas:  50.5625
# activity score:  -14.53125
